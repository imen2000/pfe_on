# %% [markdown]
# # **Libraries importing and drive mounting**

# %% [raw]
# For manipulating and analyzing data, we use pandas library (which have to installed).
# To get the timestamp, we import datetime.
# We import create_engine from the module sqlalchemy(which have to installed) to connect to the database and to create database tables.

# %%
import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine

# %% [markdown]
# # **Method Definition**

# %% [markdown]
# ### checkValue function
#
# This function gets an attribute of a specific table and validate its values against a given string collection that contains valid values and returns the result in a dataframe format which contains the same columns as the CellsMetadata table.

# %%
def checkValue(attribute, table, string_collection):
    tableName= table#get the table name 
    table= globals()[table] # convert the table name given as argument to a variable which represent the global variable table
    result= pd.DataFrame(columns=['appMethID', 'tableID','rowID', 'colID', 'timestamp', 'DQValue']) # create a dataframe named result with the same columns of CellsMetadata
    result['rowID']=table[table.columns[0]] # fill the column rowID with the row IDs
    result['DQValue']= 1*table[attribute].isin(string_collection) #check whether attribute values are validated against string_collection. Return 1 if they are valid and 0 otherwise 
    result['appMethID']=checkValue.__name__ #fill the appMethID column of the result dataframe with the name of the current function 
    result['tableID']=tableName #fill the tableID column with the name of the table given as argument
    result['colID']=attribute #fill the colID column  with the attribute name given as argument 
    result['timestamp']=datetime.now() #fill the timestamp column with the current datetime 
    return result #return the final result

# %% [markdown]
# ### check_format function

# %% [raw]
# This function checks if a given date which type is string against a specific date format and return 1 if the date correspond to the date format and 0 otherwise

# %%
def check_format(date_string,date_format): 
        try: 
            datetime.strptime(date_string,date_format) #If the string (first argument) and the date format (second argument)
            return 1                                         #passed to the strptime() doesn't match, we will get ValueError and it returns 0
        except ValueError:                                           #otherwise it will return 1
            return 0

# %% [markdown]
# ### checkFormatDate function

# %% [raw]
# This function uses the previous function check_format to check if every attribute value of a table respects the date format provided as argument and returns a dataframe that contains the same columns as the CellsMetadata table.

# %%
def checkFormatDate(attribute, table, date_format):
    tableName=table #get the table name
    table= globals()[table] # convert the table name given as argument to a variable which represent the global variable table
    result= pd.DataFrame(columns=['appMethID', 'tableID','rowID', 'colID', 'timestamp', 'DQValue']) # create a dataframe named result with the same columns of CellsMetadata
    result['rowID']=table[table.columns[0]] # fill the  rowID column with the row IDs
    result['DQValue']=  table[attribute][table[attribute].notna()].apply(lambda x: check_format(x, date_format) ) #fill the column DQValue by applying the check_format function to check if every attribute value, except NAN values, respects the given date format. 
    result['appMethID']=checkFormatDate.__name__ #fill the appMethID column  of the dataframe result with the name of the current function 
    result['tableID']=tableName  #fill the tableID column with the name of the table given as argument
    result['colID']=attribute #fill the colID column with the attribute name given as argument
    result['timestamp']=datetime.now() #fill the column timestamp with the current datetime 
    return result #return the final result

# %% [markdown]
# # **Data Loading**

# %% [raw]
# Reading the excel sheet "Patients" and put it in a dataframe with converting the 'DATE_DIAG' column type to string

# %%
patients = pd.read_excel('C:/imen/pfe_on/CHRU/Sources/CHRU_source.xlsx',sheet_name="Patients", dtype={'DATE_DIAG': str})

# %%
patients #printing the dataframe
# Out:
#         ID      SEXE         DDN                         ACT_PROF  \
# 0        1   Féminin  23/07/1939                         Retraité
# 1        2  Masculin  18/11/1941                              NaN
# 2        3  Masculin  27/10/1941                         Retraité
# 3        4  Masculin  09/09/1959  Contremaître, agent de maîtrise
# 4        5  Masculin  27/05/1960                              NaN
# ...    ...       ...         ...                              ...
# 1655  1656   Féminin  18/01/1936                              NaN
# 1656  1657   Féminin  23/01/1949             Ouvrier non qualifié
# 1657  1658   Féminin  28/11/1947                              NaN
# 1658  1659   Féminin  20/07/1940                              NaN
# 1659  1660  Masculin  23/12/1961               Cadre d'entreprise
#
#                ACT_PROF_PREC                  DIAG AUTR_DIAG      DIAG_PROBA  \
# 0     Agriculteur exploitant  Non encore déterminé       NaN             NaN
# 1                        NaN  Non encore déterminé       NaN             NaN
# 2         Cadre d'entreprise  Non encore déterminé       NaN             NaN
# 3                        NaN                   SLA       NaN  Forme certaine
# 4                        NaN                   SLA       NaN  Forme probable
# ...                      ...                   ...       ...             ...
# 1655                     NaN                   SLA       NaN  Forme certaine
# 1656                     NaN                   SLA       NaN  Forme certaine
# 1657                     NaN                   SLA       NaN  Forme probable
# 1658                     NaN                   SLA       NaN  Forme certaine
# 1659                     NaN                   SLA       NaN  Forme certaine
#
#      DATE_DIAG PREM_SYM  ...  \
# 0          NaN  juil-18  ...
# 1          NaN  janv-18  ...
# 2          NaN   déc-16  ...
# 3      juin-17  févr-17  ...
# 4       mai-17   oct-15  ...
# ...        ...      ...  ...
# 1655   mars-06  juil-05  ...
# 1656    déc-09  juil-09  ...
# 1657    nov-21   avr-21  ...
# 1658    mai-21   mai-20  ...
# 1659    déc-21   avr-21  ...
#
#      Détail de la cause du décès : [ DET_DCD_V ] [M6 - F0]  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1655                                                NaN
# 1656                                                NaN
# 1657                                                NaN
# 1658                                                NaN
# 1659                                                NaN
#
#       Détail de la cause du décès : [ DET_DCD_V ] [M8 - F0]  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1655                                                NaN
# 1656                                                NaN
# 1657                                                NaN
# 1658                                                NaN
# 1659                                                NaN
#
#      Détail de la cause du décès : [ DET_DCD_V ] [M10 - F0]  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1655                                                NaN
# 1656                                                NaN
# 1657                                                NaN
# 1658                                                NaN
# 1659                                                NaN
#
#      Détail de la cause du décès : [ DET_DCD_V ] [M14 - F0]  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1655                                                NaN
# 1656                                                NaN
# 1657                                                NaN
# 1658                                                NaN
# 1659                                                NaN
#
#      Détail de la cause du décès : [ DET_DCD_V ] [M17 - F0]  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1655                                                NaN
# 1656                                                NaN
# 1657                                                NaN
# 1658                                                NaN
# 1659                                                NaN
#
#      Détail de la cause du décès : [ DET_DCD_V ] [M18 - F0]  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1655                                                NaN
# 1656                                                NaN
# 1657                                                NaN
# 1658                                                NaN
# 1659                                                NaN
#
#      Détail de la cause du décès : [ DET_DCD_V ] [M19 - F0]  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1655                                                NaN
# 1656                                                NaN
# 1657                                                NaN
# 1658                                                NaN
# 1659                                                NaN
#
#      Détail de la cause du décès : [ DET_DCD_V ] [M20 - F0]  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1655                                                NaN
# 1656                                                NaN
# 1657                                                NaN
# 1658                                                NaN
# 1659                                                NaN
#
#      Détail de la cause du décès : [ DET_DCD_V ] [M21 - F0]  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1655                                                NaN
# 1656                                                NaN
# 1657                                                NaN
# 1658                                                NaN
# 1659                                                NaN
#
#       Détail de la cause du décès : [ DET_DCD_V ] [M30 - F0]
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1655                                                NaN
# 1656                                                NaN
# 1657                                                NaN
# 1658                                                NaN
# 1659                                                NaN
#
# [1660 rows x 536 columns]

# %% [markdown]
# # **Connection to database**

# %%
#create an engine that will allow us to connect to the postgres database by specifying the database characteristics (user=postgres,password=enisgi1,host=localhost,port=5432,database_name=new_db)
engine = create_engine('postgresql+psycopg2://postgres:test123@localhost:5432/new_db')

# %% [markdown]
# # **Method Execution and result storage**

# %% [markdown]
# ### Executing the first function and put the result in the variable result_1

# %%
result_1= checkValue('LIEU_DEBUT','patients', ['Bulbaire','Spinal','Respiratoire']) #you should enter the table that we will work with as a string and with the same name of the dataframe

# %%
result_1 #printing the result_1
# Out:
#        appMethID   tableID  rowID       colID                  timestamp  \
# 0     checkValue  patients      1  LIEU_DEBUT 2023-04-14 14:24:50.879260
# 1     checkValue  patients      2  LIEU_DEBUT 2023-04-14 14:24:50.879260
# 2     checkValue  patients      3  LIEU_DEBUT 2023-04-14 14:24:50.879260
# 3     checkValue  patients      4  LIEU_DEBUT 2023-04-14 14:24:50.879260
# 4     checkValue  patients      5  LIEU_DEBUT 2023-04-14 14:24:50.879260
# ...          ...       ...    ...         ...                        ...
# 1655  checkValue  patients   1656  LIEU_DEBUT 2023-04-14 14:24:50.879260
# 1656  checkValue  patients   1657  LIEU_DEBUT 2023-04-14 14:24:50.879260
# 1657  checkValue  patients   1658  LIEU_DEBUT 2023-04-14 14:24:50.879260
# 1658  checkValue  patients   1659  LIEU_DEBUT 2023-04-14 14:24:50.879260
# 1659  checkValue  patients   1660  LIEU_DEBUT 2023-04-14 14:24:50.879260
#
#       DQValue
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 1655        0
# 1656        0
# 1657        0
# 1658        1
# 1659        0
#
# [1660 rows x 6 columns]

# %% [markdown]
# ### Storing the result of the method checkValue in CellsMetadata Table

# %%
result_1.to_sql('CellsMetadata',engine, if_exists='append', index=False) # insert the dataframe result_1 (the result of the first executed function)  in the database table called "CellsMetadata" 
#CellsMetadata will be created only once

# %% [markdown]
# ### Executing the second function and put the result in the variable result_2

# %%
result_2= checkFormatDate('DATE_DIAG','patients','%d-%m-%Y')

# %%
result_2 #printing the result_2
# Out:
#             appMethID   tableID  rowID      colID                  timestamp  \
# 0     checkFormatDate  patients      1  DATE_DIAG 2023-04-14 14:24:50.963224
# 1     checkFormatDate  patients      2  DATE_DIAG 2023-04-14 14:24:50.963224
# 2     checkFormatDate  patients      3  DATE_DIAG 2023-04-14 14:24:50.963224
# 3     checkFormatDate  patients      4  DATE_DIAG 2023-04-14 14:24:50.963224
# 4     checkFormatDate  patients      5  DATE_DIAG 2023-04-14 14:24:50.963224
# ...               ...       ...    ...        ...                        ...
# 1655  checkFormatDate  patients   1656  DATE_DIAG 2023-04-14 14:24:50.963224
# 1656  checkFormatDate  patients   1657  DATE_DIAG 2023-04-14 14:24:50.963224
# 1657  checkFormatDate  patients   1658  DATE_DIAG 2023-04-14 14:24:50.963224
# 1658  checkFormatDate  patients   1659  DATE_DIAG 2023-04-14 14:24:50.963224
# 1659  checkFormatDate  patients   1660  DATE_DIAG 2023-04-14 14:24:50.963224
#
#       DQValue
# 0         NaN
# 1         NaN
# 2         NaN
# 3         0.0
# 4         0.0
# ...       ...
# 1655      0.0
# 1656      0.0
# 1657      0.0
# 1658      0.0
# 1659      0.0
#
# [1660 rows x 6 columns]

# %% [markdown]
# ### Storing the result of the method checkFormatDate in CellsMetadata Table

# %%
result_2.to_sql('CellsMetadata',engine, if_exists='append', index=False) # insert the dataframe result_2 (the result of the second executed function) in the database table called "CellsMetadata"
